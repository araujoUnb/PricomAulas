# %%
import pandas as pd

# %%
df = pd.read_csv('grupos.csv')

df
# Out:
#           Nome                   Sobrenome  Grupo  Notas
# 0        Laura                    Yamamoto      1    NaN
# 1        Lucca                       Lopes      1    NaN
# 2         Luiz         Phelipe de Oliveira      1    NaN
# 3        Lukas                      Araujo      1    NaN
# 4       Mateus              Jose Gonsalves      1    NaN
# 5      Matheus                       Felix      1    NaN
# 6      Thalles               Antonio Neiva      1    NaN
# 7       Daniel                     de Melo      2    NaN
# 8        Italo            Costa Cavalcante      2    NaN
# 9        Erick          Rollemberg Cruciol      2    NaN
# 10     Mariana              Ramos de Múcio      2    NaN
# 11  Emmanuelle                       Silva      2    NaN
# 12     Gabriel                       Bacon      2    NaN
# 13        Kaio                    Vinicius      2    NaN
# 14     Alander  Praxedes de Souza Oliveira      3    NaN
# ...
